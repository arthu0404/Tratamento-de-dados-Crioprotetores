# %% [markdown]
# # **Extraindo Tabela de Calibração do PDF**

# %%
import tabula

pdf_file = "cryojet_24-02-2025_11-30-14_renata_experiment.pdf"
csv_file = "tabela_extraida.csv"

tabula.convert_into(pdf_file, csv_file, output_format="csv", pages="all")
